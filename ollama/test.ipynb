# %%
from ollama import chat
from ollama import ChatResponse

response: ChatResponse = chat(model='lowllm', messages=[
  {
    'role': 'user',
    'content': 'Who are you?',
  },
])
#print(response['message']['content'])
# or access fields directly from the response object
print(response.message.content)
# Out:
# I am RimonAI, a local AI and Machine Learning assistant created by Md Raisul Islam Rimon. I run locally through Ollama and am designed to be a highly intelligent, reliable, and precise resource for AI/ML expertise.
#
# Think of me as your focused, practical guide to building and understanding real-world AI systems. I'm here to help you through the technical aspects of machine learning, deep learning, and related fields.
